# %% [markdown]
# # Load all the imports!

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler, StandardScaler


import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pylab
import seaborn as sns;
import string

# %%
# !pip install transformers
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: transformers in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (4.29.2)
# Requirement already satisfied: filelock in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from transformers) (3.29.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from transformers) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from transformers) (2026.4.4)
# Requirement already satisfied: requests in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from transformers) (2.33.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from transformers) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (1.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from requests->transformers) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from requests->transformers) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from requests->transformers) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from requests->transformers) (2026.4.22)

# %%
# !pip install huggingface_hub
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: huggingface_hub in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (0.36.2)
# Requirement already satisfied: filelock in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from huggingface_hub) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from huggingface_hub) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from huggingface_hub) (1.4.3)
# Requirement already satisfied: packaging>=20.9 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from huggingface_hub) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: requests in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from huggingface_hub) (2.33.1)
# Requirement already satisfied: tqdm>=4.42.1 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from requests->huggingface_hub) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from requests->huggingface_hub) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from requests->huggingface_hub) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from requests->huggingface_hub) (2026.4.22)

# %%
# !pip install fasttext
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: fasttext in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (0.9.3)
# Requirement already satisfied: pybind11>=2.2 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from fasttext) (3.0.4)
# Requirement already satisfied: setuptools>=0.7.0 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from fasttext) (65.5.0)
# Requirement already satisfied: numpy in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from fasttext) (1.26.4)

# %%
# !pip install torchmetrics
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: torchmetrics in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (1.9.0)
# Requirement already satisfied: numpy>1.20.0 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from torchmetrics) (26.2)
# Requirement already satisfied: torch>=2.0.0 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from torchmetrics) (2.11.0+cu130)
# Requirement already satisfied: lightning-utilities>=0.15.3 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from torchmetrics) (0.15.3)
# Requirement already satisfied: typing_extensions in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from lightning-utilities>=0.15.3->torchmetrics) (4.15.0)
# Requirement already satisfied: filelock in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (3.29.0)
# Requirement already satisfied: setuptools<82 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (65.5.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (2026.4.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (13.0.3)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from torch>=2.0.0->torchmetrics) (3.6.0)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.0.4.66)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (13.0.88)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (13.1.0.3)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (10.4.0.35)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.6.3.3)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (1.15.1.6)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (13.0.85)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (13.0.96)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (13.0.85)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.0.0.61)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from cuda-bindings<14,>=13.0.3->torch>=2.0.0->torchmetrics) (1.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.3)

# %%
# import tensorflow as tf

# # Get the GPU device name.
# device_name = tf.test.gpu_device_name()

# # The device name should look like the following:
# if device_name == '/device:GPU:0':
#     print('Found GPU at: {}'.format(device_name))
# else:
#     raise SystemError('GPU device not found')

# %%
import torch

# If there's a GPU available...
if torch.cuda.is_available():

    # Tell PyTorch to use the GPU.
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 5090

# %%
import glob
import pandas as pd
import csv
import re
import math
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from transformers import AutoTokenizer, AutoModel, AdamW, BertTokenizer, BertForSequenceClassification, GPT2Model,GPT2ForSequenceClassification
import torch

from torch import tensor
from torchmetrics.regression import KendallRankCorrCoef

import fasttext
from huggingface_hub import hf_hub_download
import matplotlib.pyplot as plt

from sklearn.utils import shuffle
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from transformers import get_linear_schedule_with_warmup
import matplotlib.pyplot as plt

import pandas as pd
import json

import random
import numpy as np
import os

# %%
# from google.colab import auth
# auth.authenticate_user()

# import gspread
# from google.auth import default
# creds, _ = default()

# gc = gspread.authorize(creds)

# %%
import os

data_path = os.path.join(os.path.dirname(os.getcwd()), 'Data',
                         'BEA 2024 Task Data Extended Shuffled - BEA 2024 Task Data Extended Shuffled.csv')
rows = pd.read_csv(data_path).to_dict('records')
print(f"Loaded {len(rows)} records from local file.")
# Out:
# Loaded 466 records from local file.

# %%
# Convert to a DataFrame and render.
import pandas as pd

dataset = pd.DataFrame.from_records(rows)
dataset
# Out:
#      ItemNum                                      ItemStem_Text  \
# 0        622  A 27-year-old man comes to the emergency depar...
# 1        440  A 39-year-old woman, gravida 2, para 2, comes ...
# 2         12  An 18-year-old primigravid woman comes for her...
# 3          5  A 26-year-old man, who is admitted to the hosp...
# 4        221  A 60-year-old man had a total thyroidectomy an...
# ..       ...                                                ...
# 461      631  A 63-year-old man with chronic obstructive pul...
# 462      457  A 58-year-old man comes to the physician becau...
# 463      114  A 25-year-old man is brought to the office by ...
# 464       27  A 78-year-old woman is admitted to the hospita...
# 465      269  A 65-year-old woman is brought to the emergenc...
#
#                                              Answer__A  \
# 0                                           Choristoma
# 1                               Future fertility plans
# 2            Repeat measurement of MSAFP concentration
# 3    There is no evidence of a familial coagulation...
# 4                    Babinski sign present bilaterally
# ..                                                 ...
# 461             Continuous nebulized albuterol therapy
# 462                                 Cremasteric artery
# 463  Advise the parents not to influence their son'...
# 464                Her eligibility to receive Medicare
# 465                                            W â†’ X
#
#                                              Answer__B  \
# 0                                   Ciliary epithelium
# 1                                         Hypertension
# 2    Triple screening for MSAFP, serum Î²-hCG, and ...
# 3    Half of their daughters will have a clinically...
# 4                                        Chvostek sign
# ..                                                 ...
# 461              CT scan of the chest without contrast
# 462                                 Pampiniform plexus
# 463   Arrange for evaluation of their son's competency
# 464              Her history of an abdominal operation
# 465                                            W â†’ Y
#
#                                              Answer__C  \
# 0                                    Endothelial cells
# 1                                              Obesity
# 2                                      Ultrasonography
# 3    The sons of their daughters will be at risk fo...
# 4             Deviation of the tongue to the left side
# ..                                                 ...
# 461                  Intravenous aminophylline therapy
# 462                                  Testicular artery
# 463    Enroll their son in a smoking cessation program
# 464                           Her history of arthritis
# 465                                            W â†’ Z
#
#                                              Answer__D  \
# 0                                       Gastric mucosa
# 1                                          Patient age
# 2    Amniocentesis for measurement of Î±-fetoprotei...
# 3    Their sons will be at risk for a clinically ev...
# 4                             A drooping left shoulder
# ..                                                 ...
# 461                         Pulmonary function testing
# 462                                    Testicular vein
# 463  Initiate a family meeting to discuss the paren...
# 464                  Her suitability for home dialysis
# 465                                            X â†’ W
#
#                                              Answer__E  \
# 0                                      Striated muscle
# 1                                     Stage of disease
# 2               Amniocentesis for chromosomal analysis
# 3    Their sons and daughters will be at risk for a...
# 4                                         Hyporeflexia
# ..                                                 ...
# 461                           Pulmonary rehabilitation
# 462                                                NaN
# 463         Obtain legal advice regarding guardianship
# 464                Her willingness to move to the city
# 465                                            X â†’ Y
#
#                    Answer__F Answer__G Answer__H  ...  \
# 0                        NaN       NaN       NaN  ...
# 1                        NaN       NaN       NaN  ...
# 2                        NaN       NaN       NaN  ...
# 3                        NaN       NaN       NaN  ...
# 4                        NaN       NaN       NaN  ...
# ..                       ...       ...       ...  ...
# 461  Titrated oxygen therapy       NaN       NaN  ...
# 462                      NaN       NaN       NaN  ...
# 463                      NaN       NaN       NaN  ...
# 464                      NaN       NaN       NaN  ...
# 465                  X â†’ Z   Z â†’ W   Z â†’ X  ...
#
#                                              all_input  \
# 0    A 27-year-old man comes to the emergency depar...
# 1    A 39-year-old woman, gravida 2, para 2, comes ...
# 2    An 18-year-old primigravid woman comes for her...
# 3    A 26-year-old man, who is admitted to the hosp...
# 4    A 60-year-old man had a total thyroidectomy an...
# ..                                                 ...
# 461  A 63-year-old man with chronic obstructive pul...
# 462  A 58-year-old man comes to the physician becau...
# 463  A 25-year-old man is brought to the office by ...
# 464  A 78-year-old woman is admitted to the hospita...
# 465  A 65-year-old woman is brought to the emergenc...
#
#                                        q_answers_input  \
# 0    A 27-year-old man comes to the emergency depar...
# 1    A 39-year-old woman, gravida 2, para 2, comes ...
# 2    An 18-year-old primigravid woman comes for her...
# 3    A 26-year-old man, who is admitted to the hosp...
# 4    A 60-year-old man had a total thyroidectomy an...
# ..                                                 ...
# 461  A 63-year-old man with chronic obstructive pul...
# 462  A 58-year-old man comes to the physician becau...
# 463  A 25-year-old man is brought to the office by ...
# 464  A 78-year-old woman is admitted to the hospita...
# 465  A 65-year-old woman is brought to the emergenc...
#
#                                          answers_input  \
# 0    Choristoma. Ciliary epithelium. Endothelial ce...
# 1    Future fertility plans. Hypertension. Obesity....
# 2    Repeat measurement of MSAFP concentration. Tri...
# 3    There is no evidence of a familial coagulation...
# 4    Babinski sign present bilaterally. Chvostek si...
# ..                                                 ...
# 461  Continuous nebulized albuterol therapy. CT sca...
# 462  Cremasteric artery. Pampiniform plexus. Testic...
# 463  Advise the parents not to influence their son'...
# 464  Her eligibility to receive Medicare. Her histo...
# 465  W â†’ X. W â†’ Y. W â†’ Z. X â†’ W. X â†’ Y. X...
#
#                                              q_a_input step_integer  \
# 0    A 27-year-old man comes to the emergency depar...            0
# 1    A 39-year-old woman, gravida 2, para 2, comes ...            2
# 2    An 18-year-old primigravid woman comes for her...            1
# 3    A 26-year-old man, who is admitted to the hosp...            2
# 4    A 60-year-old man had a total thyroidectomy an...            2
# ..                                                 ...          ...
# 461  A 63-year-old man with chronic obstructive pul...            1
# 462  A 58-year-old man comes to the physician becau...            0
# 463  A 25-year-old man is brought to the office by ...            2
# 464  A 78-year-old woman is admitted to the hospita...            2
# 465  A 65-year-old woman is brought to the emergenc...            0
#
#                                          Falcon_answer  \
# 0     (A) Ciliary epithelium (B) Endothelial cells (C)
# 1    The correct answer is C.\nThe correct answer i...
# 2    The correct answer is: C. Ultrasonography.\nTh...
# 3    The answer is E.\nThe answer is E.\nThe answer...
# 4    The correct answer is: C. Deviation of the ton...
# ..                                                 ...
# 461  The answer is: C. Intravenous aminine therapy....
# 462  The correct answer is:\nA. Cremasteric artery\...
# 463  The correct answer is A.\nThe correct answer i...
# 464                                       |endoftext|>
# 465  The correct answer is: E. X â†’ Y.\nThe ECG sh...
#
#                                        Meditron_answer  \
# 0    EOD> .\nThe authors report a case of a 45-year...
# 1    \n\n\nA. Future fertility plans\n\n\n\nB. Hype...
# 2    \n## Answer:\nThe correct answer is option C. ...
# 3    \n## Answer:\nThe correct answer is option E. ...
# 4    \n\n\nA. Babinski sign present bilaterally\n\n...
# ..                                                 ...
# 461  \n## Answer:\nThe correct answer is option A. ...
# 462  \n## Answer:\nThe correct answer is option A. ...
# 463  \n## Answer:\nThe correct answer is option C. ...
# 464  \n\n\n### Answer\n\n#### Discussion\n\nThe cor...
# 465  \n### Answer\n\nThe correct answer is option A...
#
#                                         Mistral_answer  \
# 0                                                  /s>
# 1                                                  /s>
# 2    \nThe correct answer is C. Ultrasonography.\n\...
# 3    \nThe correct answer is D.\n\nThe patient has ...
# 4    \nThe correct answer is E. Hyporeflexia.\n\nTh...
# ..                                                 ...
# 461                                                /s>
# 462  \nThe correct answer is D. Testicular vein.\n\...
# 463                                                /s>
# 464  \n## Answer\n\nThe correct answer is D. Her su...
# 465  \nThe correct answer is C.\n\nThe graph shows ...
#
#                                           llms_a_input  \
# 0    (A) Ciliary epithelium (B) Endothelial cells (...
# 1    The correct answer is C. The correct answer is...
# 2    The correct answer is: C. Ultrasonography. The...
# 3    The answer is E. The answer is E. The answer i...
# 4    The correct answer is: C. Deviation of the ton...
# ..                                                 ...
# 461  The answer is: C. Intravenous aminine therapy....
# 462  The correct answer is: A. Cremasteric artery T...
# 463  The correct answer is A. The correct answer is...
# 464  |endoftext|>. ### Answer #### Discussion The c...
# 465  The correct answer is: E. X â†’ Y. The ECG sho...
#
#                                         q_llms_a_input
# 0    A 27-year-old man comes to the emergency depar...
# 1    A 39-year-old woman, gravida 2, para 2, comes ...
# 2    An 18-year-old primigravid woman comes for her...
# 3    A 26-year-old man, who is admitted to the hosp...
# 4    A 60-year-old man had a total thyroidectomy an...
# ..                                                 ...
# 461  A 63-year-old man with chronic obstructive pul...
# 462  A 58-year-old man comes to the physician becau...
# 463  A 25-year-old man is brought to the office by ...
# 464  A 78-year-old woman is admitted to the hospita...
# 465  A 65-year-old woman is brought to the emergenc...
#
# [466 rows x 28 columns]

# %% [markdown]
# # Dataset preprocessing

# %%
def transform_column_time(df_column):
  scaler_time = MinMaxScaler()
  scores = np.array(df_column)
  scores = scores.reshape(-1,1)
  scaler_time.fit(scores)
  scores = scaler_time.transform(scores)
  scores = np.float32(scores)
  return (scores, scaler_time)

# %%
dataset['Answer__A'] = dataset['Answer__A'].apply(str)
dataset['Answer__B'] = dataset['Answer__B'].apply(str)
dataset['Answer__C'] = dataset['Answer__C'].apply(str)
dataset['Answer__D'] = dataset['Answer__D'].apply(str)
dataset['Answer__E'] = dataset['Answer__E'].apply(str)
dataset['Answer__F'] = dataset['Answer__F'].apply(str)
dataset['Answer__G'] = dataset['Answer__G'].apply(str)
dataset['Answer__H'] = dataset['Answer__H'].apply(str)
dataset['Answer__I'] = dataset['Answer__I'].apply(str)
dataset['Answer__J'] = dataset['Answer__J'].apply(str)
dataset['Answer_Key'] = dataset['Answer_Key'].apply(str)
dataset['Answer_Text'] = dataset['Answer_Text'].apply(str)
dataset['all_input'] = dataset['all_input'].apply(str)
dataset['q_answers_input'] = dataset['q_answers_input'].apply(str)
dataset['answers_input'] = dataset['answers_input'].apply(str)
dataset['q_a_input'] = dataset['q_a_input'].apply(str)
dataset['llms_a_input'] = dataset['llms_a_input'].apply(str)
dataset['q_llms_a_input'] = dataset['q_llms_a_input'].apply(str)

# %%
dataset['q_answers_llms_a_input'] = dataset['q_answers_input'] + '. ' + dataset['llms_a_input']

# %%
(dataset['Response_Time'], scaler_time) = transform_column_time(dataset['Response_Time'])

# %%
fold_1 = dataset[:92]
fold_2 = dataset[93:185]
fold_3 = dataset[186:278]
fold_4 = dataset[279:371]
fold_5 = dataset[372:465]

print(len(fold_1))
print(len(fold_2))
print(len(fold_3))
print(len(fold_4))
print(len(fold_5))
# len(fold_1.append(fold_2))
# Out:
# 92
# 92
# 92
# 92
# 93

# %% [markdown]
# #Load BERT for classification

# %%
# tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# model = BertForSequenceClassification.from_pretrained('bert-base-uncased')

tokenizer = AutoTokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token
model = GPT2ForSequenceClassification.from_pretrained("gpt2")
# Out:
# /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of GPT2ForSequenceClassification were not initialized from the model checkpoint at gpt2 and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
class CustomGPTForSeqClassification(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.gpt = GPT2ForSequenceClassification.from_pretrained("gpt2")
        self.gpt.score = torch.nn.Linear(768, 1, bias=True)
        self.gpt.config.pad_token_id = self.gpt.config.eos_token_id
        self.sigmoid = torch.nn.Sigmoid()

    def forward(self, ids, mask):
        gpt_out = self.gpt(ids, attention_mask=mask)
        # print("inainte de logits")
        # print(gpt_out.logits)
        # print(gpt_out.shape)
        sigm = self.sigmoid(gpt_out.logits)

        return (sigm)

# %%
import time
import datetime

def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))

    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
def k_fold_training(df_train, df_validation):
  print('Number of training sentences: {:,}\n'.format(df_train.shape[0]))
  print('Number of validation sentences: {:,}\n'.format(df_validation.shape[0]))

  ### TRAIN ###
  inputs_train = df_train.q_answers_input.values
  labels_train = df_train.Response_Time.values

  ### VALIDATION ###
  inputs_validation = df_validation.q_answers_input.values
  labels_validation = df_validation.Response_Time.values

  tokenizer = AutoTokenizer.from_pretrained("gpt2")
  tokenizer.pad_token = tokenizer.eos_token
  model = CustomGPTForSeqClassification()

  # Tokenize all of the sentences and map the tokens to thier word IDs.
  input_ids_train = []
  attention_masks_train = []
  # token_type_ids_train = []

  # For every webpage content.
  for content in inputs_train:
      encoded_dict = tokenizer.encode_plus(
                          content,                   # Sentence to encode.
                          add_special_tokens = True, # Add '[CLS]' and '[SEP]'
                          max_length = 300,           # Pad & truncate all sentences.
                          pad_to_max_length = True,
                          return_attention_mask = True,   # Construct attn. masks.
                          return_tensors = 'pt',     # Return pytorch tensors.
                    )
      # Add the encoded sentence to the list.
      input_ids_train.append(encoded_dict['input_ids'])

      # And its attention mask (simply differentiates padding from non-padding).
      attention_masks_train.append(encoded_dict['attention_mask'])

      # token_type_ids_train.append(encoded_dict['token_type_ids'])

  # Convert the lists into tensors.
  input_ids_train = torch.cat(input_ids_train, dim=0)
  attention_masks_train = torch.cat(attention_masks_train, dim=0)
  # token_type_ids_train = torch.cat(token_type_ids_train, dim = 0)
  labels_train = torch.tensor(labels_train)

  # # Print sentence 0, now as a list of IDs.
  # print('Original: ', inputs_train[0])
  # print('Token IDs:', input_ids_train[0])


  # Tokenize all of the sentences and map the tokens to thier word IDs.
  input_ids_validation = []
  attention_masks_validation = []
  # token_type_ids_validation = []

  # For every webpage content.
  for content in inputs_validation:
      encoded_dict = tokenizer.encode_plus(
                          content,                   # Sentence to encode.
                          add_special_tokens = True, # Add '[CLS]' and '[SEP]'
                          max_length = 300,           # Pad & truncate all sentences.
                          pad_to_max_length = True,
                          return_attention_mask = True,   # Construct attn. masks.
                          return_tensors = 'pt',     # Return pytorch tensors.
                    )

      # Add the encoded sentence to the list.
      input_ids_validation.append(encoded_dict['input_ids'])

      # And its attention mask (simply differentiates padding from non-padding).
      attention_masks_validation.append(encoded_dict['attention_mask'])

      # token_type_ids_validation.append(encoded_dict['token_type_ids'])

  # Convert the lists into tensors.
  input_ids_validation = torch.cat(input_ids_validation, dim=0)
  attention_masks_validation = torch.cat(attention_masks_validation, dim=0)
  # token_type_ids_validation = torch.cat(token_type_ids_validation, dim=0)
  labels_validation = torch.tensor(labels_validation)

  # Print sentence 0, now as a list of IDs.
  # print('Original: ', inputs_validation[0])
  # print('Token IDs:', input_ids_validation[0])


  # Combine the training inputs into a TensorDataset.
  train_dataset = TensorDataset(input_ids_train, attention_masks_train, labels_train)
  validation_dataset = TensorDataset(input_ids_validation, attention_masks_validation, labels_validation)


  batch_size = 32

  train_dataloader = DataLoader(
              train_dataset,  # The training samples.
              sampler = RandomSampler(train_dataset), # Select batches randomly
              batch_size = batch_size, # Trains with this batch size.
              num_workers=0
          )

  validation_dataloader = DataLoader(
              validation_dataset, # The validation samples.
              sampler = RandomSampler(validation_dataset), # Pull out batches sequentially.
              batch_size = batch_size, num_workers=0 # Evaluate with this batch size.
          )

  # Tell pytorch to run this model on the GPU.
  model.cuda()

  epochs = 10

  # Total number of training steps is [number of batches] x [number of epochs].
  # (Note that this is not the same as the number of training samples).
  total_steps = len(train_dataloader) * epochs

  optimizer = AdamW(model.parameters(),
                    lr = 5e-5, # args.learning_rate - default is 5e-5, our notebook had 2e-5
                    eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                  )

  # Create the learning rate scheduler.
  scheduler = get_linear_schedule_with_warmup(optimizer,
                                              num_warmup_steps = 0, # Default value in run_glue.py
                                              num_training_steps = total_steps)
  seed_val = 42

  criterion = torch.nn.MSELoss()
  kendall = KendallRankCorrCoef()

  training_stats = []
  total_t0 = time.time()

  print("train")
  # For each epoch...
  for epoch_i in range(0, epochs):

      # ========================================
      #               Training
      # ========================================

      # Perform one full pass over the training set.

      print("")
      print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
      print('Training...')

      # Measure how long the training epoch takes.
      t0 = time.time()

      # Reset the total loss for this epoch.
      total_train_loss = 0
      total_train_kendall_corr = 0
      model.train()

      # For each batch of training data...
      for step, batch in enumerate(train_dataloader):

          # Progress update every 40 batches.
          if step % 500 == 0 and not step == 0:
              # Calculate elapsed time in minutes.
              elapsed = format_time(time.time() - t0)

              # Report progress.
              print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))


          # print(batch[0])
          b_input_ids = batch[0].to(device)
          b_input_mask = batch[1].to(device)
          b_labels = batch[2].to(device)

          model.zero_grad()


          # print("aici")

          outputs = model(b_input_ids, b_input_mask)
          outputs = outputs.squeeze(1)
          # print(outputs)
          # print(b_labels)
          loss = criterion(outputs, b_labels)

          total_train_loss += loss.item()

          kendall_corr = kendall(outputs, b_labels)
          # print("Kendall corr: ", kendall_corr)
          total_train_kendall_corr += kendall_corr.item()

          loss.backward()

          # Clip the norm of the gradients to 1.0.
          # This is to help prevent the "exploding gradients" problem.
          torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

          # Update parameters and take a step using the computed gradient.
          # The optimizer dictates the "update rule"--how the parameters are
          # modified based on their gradients, the learning rate, etc.
          optimizer.step()

          # Update the learning rate.
          scheduler.step()

      # Calculate the average loss over all of the batches.
      avg_train_loss = total_train_loss / len(train_dataloader)
      avg_train_kendall_corr = total_train_kendall_corr / len(train_dataloader)

      # Measure how long this epoch took.
      training_time = format_time(time.time() - t0)

      print("")
      print("  Average training loss: {0:.4f}".format(avg_train_loss))
      print("  Average training Kendall correlation: {0:.4f}".format(avg_train_kendall_corr))
      print("  Training epoch took: {:}".format(training_time))

      # ========================================
      #               Validation
      # ========================================
      # After the completion of each training epoch, measure our performance on
      # our validation set.

      print("")
      print("Running Validation...")

      t0 = time.time()

      # Put the model in evaluation mode--the dropout layers behave differently
      # during evaluation.
      model.eval()

      # Tracking variables
      total_eval_loss = 0
      total_eval_kendall_corr = 0

      # Evaluate data for one epoch
      for batch in validation_dataloader:

          # Unpack this training batch from our dataloader.
          #
          # As we unpack the batch, we'll also copy each tensor to the GPU using
          # the `to` method.
          #
          # `batch` contains three pytorch tensors:
          #   [0]: input ids
          #   [1]: attention masks
          #   [2]: labels
          b_input_ids = batch[0].to(device)
          b_input_mask = batch[1].to(device)
          b_labels = batch[2].to(device)

          with torch.no_grad():
              outputs = model(b_input_ids, b_input_mask)

          outputs = outputs.squeeze(1)
          kendall_corr = kendall(outputs, b_labels)

          loss = criterion(outputs, b_labels)
          # Accumulate the validation loss.
          total_eval_loss += loss.item()
          total_eval_kendall_corr += kendall_corr.item()

      # Calculate the average loss over all of the batches.
      avg_val_loss = total_eval_loss / len(validation_dataloader)
      avg_val_kendall_corr = total_eval_kendall_corr / len(validation_dataloader)
      # Measure how long the validation run took.
      validation_time = format_time(time.time() - t0)
      print("  Validation Loss: {0:.4f}".format(avg_val_loss))
      print("  Validation Kendall correlation: {0:.4f}".format(avg_val_kendall_corr))
      print("  Validation took: {:}".format(validation_time))

      # Record all statistics from this epoch.
      training_stats.append(
          {
              'epoch': epoch_i + 1,
              'Training Loss': avg_train_loss,
              'Valid. Loss': avg_val_loss,
              'Training Kendall corr.': avg_train_kendall_corr,
              'Valid. Kendall corr.': avg_val_kendall_corr,
              'Training Time': training_time,
              'Validation Time': validation_time,
          }
      )

  print("")
  print("Training complete!")

  print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
  # Display floats with two decimal places.
  # pd.set_option('precision', 6)

  # Create a DataFrame from our training statistics.
  df_stats = pd.DataFrame(data=training_stats)

  # Use the 'epoch' as the row index.
  df_stats = df_stats.set_index('epoch')

  # A hack to force the column headers to wrap.
  #df = df.style.set_table_styles([dict(selector="th",props=[('max-width', '70px')])])

  # Display the table.
  print(df_stats)

  return model

# %% [markdown]
# # Run 1
#
# Validation = fold_1, fold_2
#
# Train = fold_3 + fold_4 + fold_5

# %%
# df_validation = fold_1

# df_train = fold_2.append(fold_3)
# df_train = df_train.append(fold_4)
# df_train = df_train.append(fold_5)

# model = k_fold_training(df_train, df_validation)

# %% [markdown]
# # Run 2
#
# Validation = fold_2 + fold_3
#
# Train = fold_1 + fold_4 + fold_5

# %%
# df_validation = fold_2

# df_train = fold_1.append(fold_3)
# df_train = df_train.append(fold_4)
# df_train = df_train.append(fold_5)

# fine_tuned_model = k_fold_training(df_train, df_validation)

# %% [markdown]
# # Run 3
#
# Validation = fold_3
#
# Train = fold_1 + fold_2 + fold_4 + fold_5

# %%
# df_validation = fold_3

# df_train = fold_1.append(fold_2)
# df_train = df_train.append(fold_4)
# df_train = df_train.append(fold_5)

# model = k_fold_training(df_train, df_validation)

# %% [markdown]
# # Run 4
#
# Validation = fold_4
#
# Train = fold_1 + fold_2 + fold_3 + fold_5

# %%
# df_validation = fold_4

# df_train = fold_1.append(fold_2)
# df_train = df_train.append(fold_3)
# df_train = df_train.append(fold_5)

# k_fold_training(df_train, df_validation)

# %% [markdown]
# # Run 5
#
# Validation = fold_5
#
# Train = fold_1 + fold_2 + fold_3 + fold_4

# %%
# df_validation = fold_5

# df_train = fold_1.append(fold_2)
# df_train = df_train.append(fold_3)
# df_train = df_train.append(fold_4)

# k_fold_training(df_train, df_validation)

# %%
df_train = fold_1.append(fold_2)
df_train = df_train.append(fold_3)
df_train = df_train.append(fold_4)
df_train = df_train.append(fold_5)

print('Number of training sentences: {:,}\n'.format(df_train.shape[0]))

### TRAIN ###
inputs_train = df_train.q_answers_input.values
labels_train = df_train.Response_Time.values

tokenizer = AutoTokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token
model = CustomGPTForSeqClassification()

# Tokenize all of the sentences and map the tokens to thier word IDs.
input_ids_train = []
attention_masks_train = []
# token_type_ids_train = []

# For every webpage content.
for content in inputs_train:
    encoded_dict = tokenizer.encode_plus(
                        content,                   # Sentence to encode.
                        add_special_tokens = True, # Add '[CLS]' and '[SEP]'
                        max_length = 300,           # Pad & truncate all sentences.
                        pad_to_max_length = True,
                        return_attention_mask = True,   # Construct attn. masks.
                        return_tensors = 'pt',     # Return pytorch tensors.
                  )
    # Add the encoded sentence to the list.
    input_ids_train.append(encoded_dict['input_ids'])

    # And its attention mask (simply differentiates padding from non-padding).
    attention_masks_train.append(encoded_dict['attention_mask'])

    # token_type_ids_train.append(encoded_dict['token_type_ids'])

# Convert the lists into tensors.
input_ids_train = torch.cat(input_ids_train, dim=0)
attention_masks_train = torch.cat(attention_masks_train, dim=0)
# token_type_ids_train = torch.cat(token_type_ids_train, dim = 0)
labels_train = torch.tensor(labels_train)

# # Print sentence 0, now as a list of IDs.
# print('Original: ', inputs_train[0])
# print('Token IDs:', input_ids_train[0])

# Combine the training inputs into a TensorDataset.
train_dataset = TensorDataset(input_ids_train, attention_masks_train, labels_train)

batch_size = 32

train_dataloader = DataLoader(
            train_dataset,  # The training samples.
            sampler = RandomSampler(train_dataset), # Select batches randomly
            batch_size = batch_size, # Trains with this batch size.
            num_workers=0
        )

# Tell pytorch to run this model on the GPU.
model.cuda()

epochs = 10

# Total number of training steps is [number of batches] x [number of epochs].
# (Note that this is not the same as the number of training samples).
total_steps = len(train_dataloader) * epochs

optimizer = AdamW(model.parameters(),
                  lr = 5e-5, # args.learning_rate - default is 5e-5, our notebook had 2e-5
                  eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                )

# Create the learning rate scheduler.
scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps = 0, # Default value in run_glue.py
                                            num_training_steps = total_steps)
seed_val = 42

criterion = torch.nn.MSELoss()
kendall = KendallRankCorrCoef()

training_stats = []
total_t0 = time.time()

print("train")
# For each epoch...
for epoch_i in range(0, epochs):

    # ========================================
    #               Training
    # ========================================

    # Perform one full pass over the training set.

    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    # Measure how long the training epoch takes.
    t0 = time.time()

    # Reset the total loss for this epoch.
    total_train_loss = 0
    total_train_kendall_corr = 0
    model.train()

    # For each batch of training data...
    for step, batch in enumerate(train_dataloader):

        # Progress update every 40 batches.
        if step % 500 == 0 and not step == 0:
            # Calculate elapsed time in minutes.
            elapsed = format_time(time.time() - t0)

            # Report progress.
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))


        # print(batch[0])
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)

        model.zero_grad()


        # print("aici")

        outputs = model(b_input_ids, b_input_mask)
        outputs = outputs.squeeze(1)
        # print(outputs)
        # print(b_labels)
        loss = criterion(outputs, b_labels)

        total_train_loss += loss.item()

        kendall_corr = kendall(outputs, b_labels)
        # print("Kendall corr: ", kendall_corr)
        total_train_kendall_corr += kendall_corr.item()

        loss.backward()

        # Clip the norm of the gradients to 1.0.
        # This is to help prevent the "exploding gradients" problem.
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        # Update parameters and take a step using the computed gradient.
        # The optimizer dictates the "update rule"--how the parameters are
        # modified based on their gradients, the learning rate, etc.
        optimizer.step()

        # Update the learning rate.
        scheduler.step()

    # Calculate the average loss over all of the batches.
    avg_train_loss = total_train_loss / len(train_dataloader)
    avg_train_kendall_corr = total_train_kendall_corr / len(train_dataloader)

    # Measure how long this epoch took.
    training_time = format_time(time.time() - t0)

    print("")
    print("  Average training loss: {0:.4f}".format(avg_train_loss))
    print("  Average training Kendall correlation: {0:.4f}".format(avg_train_kendall_corr))
    print("  Training epoch took: {:}".format(training_time))

    # Record all statistics from this epoch.
    training_stats.append(
        {
            'epoch': epoch_i + 1,
            'Training Loss': avg_train_loss,
            'Training Kendall corr.': avg_train_kendall_corr,
            'Training Time': training_time,
        }
    )

print("")
print("Training complete!")

print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
# Display floats with two decimal places.
# pd.set_option('precision', 6)

# Create a DataFrame from our training statistics.
df_stats = pd.DataFrame(data=training_stats)

# Use the 'epoch' as the row index.
df_stats = df_stats.set_index('epoch')

# A hack to force the column headers to wrap.
#df = df.style.set_table_styles([dict(selector="th",props=[('max-width', '70px')])])

# Display the table.
print(df_stats)
# Out:
# /tmp/ipykernel_79505/502852368.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train = fold_1.append(fold_2)
# /tmp/ipykernel_79505/502852368.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train = df_train.append(fold_3)
# /tmp/ipykernel_79505/502852368.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train = df_train.append(fold_4)
# /tmp/ipykernel_79505/502852368.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train = df_train.append(fold_5)
# /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Number of training sentences: 461
# Some weights of GPT2ForSequenceClassification were not initialized from the model checkpoint at gpt2 and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2364: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages/transformers/optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# train
#
# ======== Epoch 1 / 10 ========
# Training...
#
#   Average training loss: 0.0357
#   Average training Kendall correlation: 0.0834
#   Training epoch took: 0:00:03
#
# ======== Epoch 2 / 10 ========
# Training...
#
#   Average training loss: 0.0168
#   Average training Kendall correlation: 0.3072
#   Training epoch took: 0:00:03
#
# ======== Epoch 3 / 10 ========
# Training...
#
#   Average training loss: 0.0120
#   Average training Kendall correlation: 0.4622
#   Training epoch took: 0:00:03
#
# ======== Epoch 4 / 10 ========
# Training...
#
#   Average training loss: 0.0093
#   Average training Kendall correlation: 0.5323
#   Training epoch took: 0:00:03
#
# ======== Epoch 5 / 10 ========
# Training...
#
#   Average training loss: 0.0078
#   Average training Kendall correlation: 0.5829
#   Training epoch took: 0:00:03
#
# ======== Epoch 6 / 10 ========
# Training...
#
#   Average training loss: 0.0052
#   Average training Kendall correlation: 0.6236
#   Training epoch took: 0:00:03
#
# ======== Epoch 7 / 10 ========
# Training...
#
#   Average training loss: 0.0050
#   Average training Kendall correlation: 0.6402
#   Training epoch took: 0:00:03
#
# ======== Epoch 8 / 10 ========
# Training...
#
#   Average training loss: 0.0044
#   Average training Kendall correlation: 0.6929
#   Training epoch took: 0:00:03
#
# ======== Epoch 9 / 10 ========
# Training...
#
#   Average training loss: 0.0046
#   Average training Kendall correlation: 0.6720
#   Training epoch took: 0:00:03
#
# ======== Epoch 10 / 10 ========
# Training...
#
#   Average training loss: 0.0039
#   Average training Kendall correlation: 0.7019
#   Training epoch took: 0:00:03
#
# Training complete!
# Total training took 0:00:27 (h:mm:ss)
#        Training Loss  Training Kendall corr. Training Time
# epoch
# 1           0.035737                0.083354       0:00:03
# 2           0.016808                0.307161       0:00:03
# 3           0.012008                0.462166       0:00:03
# 4           0.009311                0.532306       0:00:03
# 5           0.007818                0.582892       0:00:03
# 6           0.005223                0.623572       0:00:03
# 7           0.004980                0.640240       0:00:03
# 8           0.004371                0.692887       0:00:03
# 9           0.004614                0.671972       0:00:03
# 10          0.003919                0.701899       0:00:03

# %% [markdown]
# # Evaluate on test set

# %%
test_data_path = os.path.join(os.path.dirname(os.getcwd()), 'Data',
                              'BEA 2024 Test Data Extended - Sheet 1.csv')
dataset = pd.read_csv(test_data_path)
print(f"Loaded {len(dataset)} test records from local file.")
# Out:
# Loaded 201 test records from local file.

# %%
# Test dataset loaded above
dataset
# Out:
#      ItemNum                                      ItemStem_Text  \
# 0        552  A 78-year-old woman undergoes an outpatient la...
# 1         16  A 48-year-old man dies suddenly of a cardiac a...
# 2        441  A study is being conducted to assess mesotheli...
# 3        219  A 68-year-old man comes to the office because ...
# 4        600  A 20-year-old woman is brought to the urgent c...
# ..       ...                                                ...
# 196      612  A 45-year-old man is brought to the clinic by ...
# 197      315  A 64-year-old man with non-Hodgkin lymphoma co...
# 198      509  A 9-month-old boy is brought to the office by ...
# 199      550  A 32-year-old man comes to the office because ...
# 200      290  A study is conducted to assess the effects of ...
#
#                          Answer__A  \
# 0                   Gastroduodenal
# 1               Acute inflammation
# 2              Address confounding
# 3                              Age
# 4                             Diet
# ..                             ...
# 196                        Atrophy
# 197                      Bleomycin
# 198      Abdominal ultrasonography
# 199                       Collagen
# 200  Increased cAMP decreased cAMP
#
#                                             Answer__B  \
# 0                                        Left gastric
# 1                                   Fibrinous exudate
# 2                               Demonstrate causality
# 3                                              Gender
# 4                                      Family illness
# ..                                                ...
# 196                           Decreased visual acuity
# 197                                  Cyclophosphamide
# 198  Antiâ€“Saccharomyces cerevisiae antibody testing
# 199                               Double-stranded DNA
# 200                     Increased cAMP decreased cGMP
#
#                          Answer__C  \
# 0                     Left hepatic
# 1                     Fibrous scar
# 2      Minimize ascertainment bias
# 3        History of osteoarthritis
# 4                    Recent travel
# ..                             ...
# 196         Loss of proprioception
# 197                     Cytarabine
# 198  Nitroblue tetrazolium testing
# 199              Nucleolar protein
# 200  Increased cGMP decreased cAMP
#
#                                              Answer__D  \
# 0                                        Right gastric
# 1                                   Granulation tissue
# 2                                   Reduce recall bias
# 3                                  Previous occupation
# 4                                               Trauma
# ..                                                 ...
# 196                     Presence of palmomental reflex
# 197                                        Doxorubicin
# 198              Rectal swab for group B streptococcus
# 199                                       Phospholipid
# 200  Increased cGMP decreased phosphoinositide turn...
#
#                                              Answer__E  \
# 0                                        Right hepatic
# 1                                        Normal kidney
# 2                                                  NaN
# 3                                   Use of pravastatin
# 4                               Unintended weight loss
# ..                                                 ...
# 196                                             Ptosis
# 197                                       Fluorouracil
# 198                                    Skeletal survey
# 199                   Proteins in neutrophil cytoplasm
# 200  Increased phosphoinositide turnover decreased ...
#
#                                              Answer__F    Answer__G Answer__H  \
# 0                                                  NaN          NaN       NaN
# 1                                                  NaN          NaN       NaN
# 2                                                  NaN          NaN       NaN
# 3                                                  NaN          NaN       NaN
# 4                                                  NaN          NaN       NaN
# ..                                                 ...          ...       ...
# 196                                                NaN          NaN       NaN
# 197                                       Methotrexate  Vincristine       NaN
# 198           Stool culture for Salmonella enteritidis          NaN       NaN
# 199                                                NaN          NaN       NaN
# 200  Increased phosphoinositide turnover increased ...          NaN       NaN
#
#      ...                                      answers_input  \
# 0    ...  Gastroduodenal. Left gastric. Left hepatic. Ri...
# 1    ...  Acute inflammation. Fibrinous exudate. Fibrous...
# 2    ...  Address confounding. Demonstrate causality. Mi...
# 3    ...  Age. Gender. History of osteoarthritis. Previo...
# 4    ...  Diet. Family illness. Recent travel. Trauma. U...
# ..   ...                                                ...
# 196  ...  Atrophy. Decreased visual acuity. Loss of prop...
# 197  ...  Bleomycin. Cyclophosphamide. Cytarabine. Doxor...
# 198  ...  Abdominal ultrasonography. Antiâ€“Saccharomyce...
# 199  ...  Collagen. Double-stranded DNA. Nucleolar prote...
# 200  ...  Increased cAMP decreased cAMP. Increased cAMP ...
#
#                                              q_a_input step_integer  \
# 0    A 78-year-old woman undergoes an outpatient la...            0
# 1    A 48-year-old man dies suddenly of a cardiac a...            0
# 2    A study is being conducted to assess mesotheli...            1
# 3    A 68-year-old man comes to the office because ...            1
# 4    A 20-year-old woman is brought to the urgent c...            0
# ..                                                 ...          ...
# 196  A 45-year-old man is brought to the clinic by ...            0
# 197  A 64-year-old man with non-Hodgkin lymphoma co...            0
# 198  A 9-month-old boy is brought to the office by ...            2
# 199  A 32-year-old man comes to the office because ...            0
# 200  A study is conducted to assess the effects of ...            0
#
#                                          Falcon_answer  \
# 0    The correct answer is:\nA. Gastroduodenal\nThe...
# 1    The answer is E. Normal kidney.\nThe normal ki...
# 2    The correct answer is: C. Minimize ascertainme...
# 3                                         |endoftext|>
# 4    The correct answer is: E. Unintended weight lo...
# ..                                                 ...
# 196                                      <|endoftext|>
# 197  The correct answer is: D. Doxorubicin.\nDoxoru...
# 198  The answer is A.\nThe answer is A.\nThe answer...
# 199  The answer is A. Collagen.\nThe answer is A. C...
# 200                                      <|endoftext|>
#
#                                        Meditron_answer  \
# 0    \n## Answer:\nThe correct answer is option A. ...
# 1    \n## Answer:\nThe correct answer is option A. ...
# 2    \n### Answer\n\n### A. Address confounding\n\n...
# 3    EOD> .\nThe authors report a case of a 45-year...
# 4    \n## Answer:\nThe correct answer is option A. ...
# ..                                                 ...
# 196  \n## Answer:\nA. Atrophy\n\n## Comment:\nThe c...
# 197  \n## Answer:\nThe correct answer is option A. ...
# 198  EOD> .\nThe authors report a case of a 45-year...
# 199      A. Collagen\nB. Double-stranded DNA\nC. Nucle
# 200  \n## Answer:\nThe correct answer is option A. ...
#
#                                         Mistral_answer  \
# 0    \nThe correct answer is E. The cystic artery i...
# 1    \nThe correct answer is C. Fibrous scar.\n\nTh...
# 2                                                  /s>
# 3                                                  /s>
# 4    \nThe correct answer is B. Family illness.\n\n...
# ..                                                 ...
# 196  \nThe correct answer is C.\n\nThe patient has ...
# 197   \nThe correct answer is D. Doxorubicin.\n\nDoxor
# 198  \nThe correct answer is E.\n\nThe child has a ...
# 199                                                /s>
# 200  \nThe correct answer is F.\n\nEpinephrine is a...
#
#                                           llms_a_input  \
# 0    The correct answer is: A. Gastroduodenal The c...
# 1    The answer is E. Normal kidney. The normal kid...
# 2    The correct answer is: C. Minimize ascertainme...
# 3    |endoftext|>. EOD> . The authors report a case...
# 4    The correct answer is: E. Unintended weight lo...
# ..                                                 ...
# 196  <|endoftext|>. ## Answer: A. Atrophy ## Commen...
# 197  The correct answer is: D. Doxorubicin. Doxorub...
# 198  The answer is A. The answer is A. The answer i...
# 199  The answer is A. Collagen. The answer is A. Co...
# 200  <|endoftext|>. ## Answer: The correct answer i...
#
#                                         q_llms_a_input Difficulty  \
# 0    A 78-year-old woman undergoes an outpatient la...       0.52
# 1    A 48-year-old man dies suddenly of a cardiac a...       0.70
# 2    A study is being conducted to assess mesotheli...       0.84
# 3    A 68-year-old man comes to the office because ...       1.02
# 4    A 20-year-old woman is brought to the urgent c...       0.96
# ..                                                 ...        ...
# 196  A 45-year-old man is brought to the clinic by ...       0.22
# 197  A 64-year-old man with non-Hodgkin lymphoma co...       0.14
# 198  A 9-month-old boy is brought to the office by ...       0.94
# 199  A 32-year-old man comes to the office because ...       0.30
# 200  A study is conducted to assess the effects of ...       0.70
#
#     Response_Time
# 0           75.21
# 1           80.88
# 2           88.45
# 3          127.30
# 4           88.57
# ..            ...
# 196         95.17
# 197         42.72
# 198        122.73
# 199         86.13
# 200        142.71
#
# [201 rows x 28 columns]

# %%
scores = np.array(dataset['Response_Time'])
scores = scores.reshape(-1,1)
scores = scaler_time.transform(scores)
dataset['Response_Time'] = np.float32(scores)

# %%
labels_test = dataset.Response_Time.values
labels_test = torch.tensor(labels_test)

# %%
dataset
# Out:
#      ItemNum                                      ItemStem_Text  \
# 0        552  A 78-year-old woman undergoes an outpatient la...
# 1         16  A 48-year-old man dies suddenly of a cardiac a...
# 2        441  A study is being conducted to assess mesotheli...
# 3        219  A 68-year-old man comes to the office because ...
# 4        600  A 20-year-old woman is brought to the urgent c...
# ..       ...                                                ...
# 196      612  A 45-year-old man is brought to the clinic by ...
# 197      315  A 64-year-old man with non-Hodgkin lymphoma co...
# 198      509  A 9-month-old boy is brought to the office by ...
# 199      550  A 32-year-old man comes to the office because ...
# 200      290  A study is conducted to assess the effects of ...
#
#                          Answer__A  \
# 0                   Gastroduodenal
# 1               Acute inflammation
# 2              Address confounding
# 3                              Age
# 4                             Diet
# ..                             ...
# 196                        Atrophy
# 197                      Bleomycin
# 198      Abdominal ultrasonography
# 199                       Collagen
# 200  Increased cAMP decreased cAMP
#
#                                             Answer__B  \
# 0                                        Left gastric
# 1                                   Fibrinous exudate
# 2                               Demonstrate causality
# 3                                              Gender
# 4                                      Family illness
# ..                                                ...
# 196                           Decreased visual acuity
# 197                                  Cyclophosphamide
# 198  Antiâ€“Saccharomyces cerevisiae antibody testing
# 199                               Double-stranded DNA
# 200                     Increased cAMP decreased cGMP
#
#                          Answer__C  \
# 0                     Left hepatic
# 1                     Fibrous scar
# 2      Minimize ascertainment bias
# 3        History of osteoarthritis
# 4                    Recent travel
# ..                             ...
# 196         Loss of proprioception
# 197                     Cytarabine
# 198  Nitroblue tetrazolium testing
# 199              Nucleolar protein
# 200  Increased cGMP decreased cAMP
#
#                                              Answer__D  \
# 0                                        Right gastric
# 1                                   Granulation tissue
# 2                                   Reduce recall bias
# 3                                  Previous occupation
# 4                                               Trauma
# ..                                                 ...
# 196                     Presence of palmomental reflex
# 197                                        Doxorubicin
# 198              Rectal swab for group B streptococcus
# 199                                       Phospholipid
# 200  Increased cGMP decreased phosphoinositide turn...
#
#                                              Answer__E  \
# 0                                        Right hepatic
# 1                                        Normal kidney
# 2                                                  NaN
# 3                                   Use of pravastatin
# 4                               Unintended weight loss
# ..                                                 ...
# 196                                             Ptosis
# 197                                       Fluorouracil
# 198                                    Skeletal survey
# 199                   Proteins in neutrophil cytoplasm
# 200  Increased phosphoinositide turnover decreased ...
#
#                                              Answer__F    Answer__G Answer__H  \
# 0                                                  NaN          NaN       NaN
# 1                                                  NaN          NaN       NaN
# 2                                                  NaN          NaN       NaN
# 3                                                  NaN          NaN       NaN
# 4                                                  NaN          NaN       NaN
# ..                                                 ...          ...       ...
# 196                                                NaN          NaN       NaN
# 197                                       Methotrexate  Vincristine       NaN
# 198           Stool culture for Salmonella enteritidis          NaN       NaN
# 199                                                NaN          NaN       NaN
# 200  Increased phosphoinositide turnover increased ...          NaN       NaN
#
#      ...                                      answers_input  \
# 0    ...  Gastroduodenal. Left gastric. Left hepatic. Ri...
# 1    ...  Acute inflammation. Fibrinous exudate. Fibrous...
# 2    ...  Address confounding. Demonstrate causality. Mi...
# 3    ...  Age. Gender. History of osteoarthritis. Previo...
# 4    ...  Diet. Family illness. Recent travel. Trauma. U...
# ..   ...                                                ...
# 196  ...  Atrophy. Decreased visual acuity. Loss of prop...
# 197  ...  Bleomycin. Cyclophosphamide. Cytarabine. Doxor...
# 198  ...  Abdominal ultrasonography. Antiâ€“Saccharomyce...
# 199  ...  Collagen. Double-stranded DNA. Nucleolar prote...
# 200  ...  Increased cAMP decreased cAMP. Increased cAMP ...
#
#                                              q_a_input step_integer  \
# 0    A 78-year-old woman undergoes an outpatient la...            0
# 1    A 48-year-old man dies suddenly of a cardiac a...            0
# 2    A study is being conducted to assess mesotheli...            1
# 3    A 68-year-old man comes to the office because ...            1
# 4    A 20-year-old woman is brought to the urgent c...            0
# ..                                                 ...          ...
# 196  A 45-year-old man is brought to the clinic by ...            0
# 197  A 64-year-old man with non-Hodgkin lymphoma co...            0
# 198  A 9-month-old boy is brought to the office by ...            2
# 199  A 32-year-old man comes to the office because ...            0
# 200  A study is conducted to assess the effects of ...            0
#
#                                          Falcon_answer  \
# 0    The correct answer is:\nA. Gastroduodenal\nThe...
# 1    The answer is E. Normal kidney.\nThe normal ki...
# 2    The correct answer is: C. Minimize ascertainme...
# 3                                         |endoftext|>
# 4    The correct answer is: E. Unintended weight lo...
# ..                                                 ...
# 196                                      <|endoftext|>
# 197  The correct answer is: D. Doxorubicin.\nDoxoru...
# 198  The answer is A.\nThe answer is A.\nThe answer...
# 199  The answer is A. Collagen.\nThe answer is A. C...
# 200                                      <|endoftext|>
#
#                                        Meditron_answer  \
# 0    \n## Answer:\nThe correct answer is option A. ...
# 1    \n## Answer:\nThe correct answer is option A. ...
# 2    \n### Answer\n\n### A. Address confounding\n\n...
# 3    EOD> .\nThe authors report a case of a 45-year...
# 4    \n## Answer:\nThe correct answer is option A. ...
# ..                                                 ...
# 196  \n## Answer:\nA. Atrophy\n\n## Comment:\nThe c...
# 197  \n## Answer:\nThe correct answer is option A. ...
# 198  EOD> .\nThe authors report a case of a 45-year...
# 199      A. Collagen\nB. Double-stranded DNA\nC. Nucle
# 200  \n## Answer:\nThe correct answer is option A. ...
#
#                                         Mistral_answer  \
# 0    \nThe correct answer is E. The cystic artery i...
# 1    \nThe correct answer is C. Fibrous scar.\n\nTh...
# 2                                                  /s>
# 3                                                  /s>
# 4    \nThe correct answer is B. Family illness.\n\n...
# ..                                                 ...
# 196  \nThe correct answer is C.\n\nThe patient has ...
# 197   \nThe correct answer is D. Doxorubicin.\n\nDoxor
# 198  \nThe correct answer is E.\n\nThe child has a ...
# 199                                                /s>
# 200  \nThe correct answer is F.\n\nEpinephrine is a...
#
#                                           llms_a_input  \
# 0    The correct answer is: A. Gastroduodenal The c...
# 1    The answer is E. Normal kidney. The normal kid...
# 2    The correct answer is: C. Minimize ascertainme...
# 3    |endoftext|>. EOD> . The authors report a case...
# 4    The correct answer is: E. Unintended weight lo...
# ..                                                 ...
# 196  <|endoftext|>. ## Answer: A. Atrophy ## Commen...
# 197  The correct answer is: D. Doxorubicin. Doxorub...
# 198  The answer is A. The answer is A. The answer i...
# 199  The answer is A. Collagen. The answer is A. Co...
# 200  <|endoftext|>. ## Answer: The correct answer i...
#
#                                         q_llms_a_input Difficulty  \
# 0    A 78-year-old woman undergoes an outpatient la...       0.52
# 1    A 48-year-old man dies suddenly of a cardiac a...       0.70
# 2    A study is being conducted to assess mesotheli...       0.84
# 3    A 68-year-old man comes to the office because ...       1.02
# 4    A 20-year-old woman is brought to the urgent c...       0.96
# ..                                                 ...        ...
# 196  A 45-year-old man is brought to the clinic by ...       0.22
# 197  A 64-year-old man with non-Hodgkin lymphoma co...       0.14
# 198  A 9-month-old boy is brought to the office by ...       0.94
# 199  A 32-year-old man comes to the office because ...       0.30
# 200  A study is conducted to assess the effects of ...       0.70
#
#     Response_Time
# 0        0.238307
# 1        0.266311
# 2        0.303699
# 3        0.495580
# 4        0.304292
# ..            ...
# 196      0.336889
# 197      0.077839
# 198      0.473008
# 199      0.292241
# 200      0.571690
#
# [201 rows x 28 columns]

# %%
dataset['Answer__A'] = dataset['Answer__A'].apply(str)
dataset['Answer__B'] = dataset['Answer__B'].apply(str)
dataset['Answer__C'] = dataset['Answer__C'].apply(str)
dataset['Answer__D'] = dataset['Answer__D'].apply(str)
dataset['Answer__E'] = dataset['Answer__E'].apply(str)
dataset['Answer__F'] = dataset['Answer__F'].apply(str)
dataset['Answer__G'] = dataset['Answer__G'].apply(str)
dataset['Answer__H'] = dataset['Answer__H'].apply(str)
dataset['Answer__I'] = dataset['Answer__I'].apply(str)
dataset['Answer__J'] = dataset['Answer__J'].apply(str)
dataset['Answer_Key'] = dataset['Answer_Key'].apply(str)
dataset['Answer_Text'] = dataset['Answer_Text'].apply(str)
dataset['all_input'] = dataset['all_input'].apply(str)
dataset['q_answers_input'] = dataset['q_answers_input'].apply(str)
dataset['answers_input'] = dataset['answers_input'].apply(str)
dataset['q_a_input'] = dataset['q_a_input'].apply(str)
dataset['llms_a_input'] = dataset['llms_a_input'].apply(str)
dataset['q_llms_a_input'] = dataset['q_llms_a_input'].apply(str)

# %%
inputs_test = dataset.q_answers_input.values

# Tokenize all of the sentences and map the tokens to thier word IDs.
input_ids_test = []
attention_masks_test = []
token_type_ids_test = []

# For every webpage content.
for content in inputs_test:
    encoded_dict = tokenizer.encode_plus(
                        content,                   # Sentence to encode.
                        add_special_tokens = True, # Add '[CLS]' and '[SEP]'
                        max_length = 300,           # Pad & truncate all sentences.
                        pad_to_max_length = True,
                        return_attention_mask = True,   # Construct attn. masks.
                        return_tensors = 'pt',     # Return pytorch tensors.
                  )

    # Add the encoded sentence to the list.
    input_ids_test.append(encoded_dict['input_ids'])

    # And its attention mask (simply differentiates padding from non-padding).
    attention_masks_test.append(encoded_dict['attention_mask'])

    # token_type_ids_test.append(encoded_dict['token_type_ids'])

# Convert the lists into tensors.
input_ids_test = torch.cat(input_ids_test, dim=0)
attention_masks_test = torch.cat(attention_masks_test, dim=0)
# token_type_ids_test = torch.cat(token_type_ids_test, dim=0)
item_nums_test = torch.tensor(dataset.ItemNum.values)
test_dataset = TensorDataset(input_ids_test, attention_masks_test, item_nums_test, labels_test)
# Out:
# /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2364: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
test_dataloader = DataLoader(test_dataset,
                             sampler=SequentialSampler(test_dataset),
                             batch_size=32)

# %%
# Prediction on test set

print('Predicting labels for {:,} test sentences...'.format(len(input_ids_test)))

# Put model in evaluation mode
model.eval()

# Tracking variables
item_nums = []
predictions = []

total_test_loss = 0
total_test_kendall = 0

criterion = torch.nn.MSELoss()
kendall = KendallRankCorrCoef()

# Predict
for batch in test_dataloader:
  # Add batch to GPU
  batch = tuple(t.to(device) for t in batch)

  # Unpack the inputs from our dataloader
  b_input_ids, b_input_mask, b_item_nums, b_labels = batch

  # Telling the model not to compute or store gradients, saving memory and
  # speeding up prediction
  with torch.no_grad():
    outputs = model(b_input_ids, b_input_mask)

  loss = criterion(outputs, b_labels)

  total_test_loss += loss.item()

  kendall_corr = kendall(outputs.flatten(), b_labels)
  total_test_kendall += kendall_corr


  predicted_labels = outputs.detach().cpu().numpy()
  current_item_nums = b_item_nums.to('cpu').numpy()

  # Store predictions and true labels
  predictions = np.append(predictions, predicted_labels)
  item_nums = np.append(item_nums, current_item_nums)

print('    DONE.')
# Calculate the average loss over all of the batches.
avg_test_loss = total_test_loss / len(test_dataloader)
avg_test_kendall_corr = total_test_kendall / len(test_dataloader)
print("  Validation Loss: {0:.4f}".format(avg_test_loss))
print("  Validation Kendall correlation: {0:.4f}".format(avg_test_kendall_corr))
# Out:
# /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages/torch/nn/modules/loss.py:626: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Predicting labels for 201 test sentences...
#     DONE.
#   Validation Loss: 0.0345
#   Validation Kendall correlation: 0.3719
# /home/bojingyy/CSEN 346/BEA-2024/venv/lib/python3.10/site-packages/torch/nn/modules/loss.py:626: UserWarning: Using a target size (torch.Size([9])) that is different to the input size (torch.Size([9, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)

# %%
predictions = predictions.reshape(-1,1)
predictions = scaler_time.inverse_transform(predictions)

# %%
predictions = predictions.flatten()

# %%
item_nums = item_nums.astype(int)

# %%
d = {'ItemNum': item_nums, 'Prediction': predictions}
df = pd.DataFrame(data=d)
df
# Out:
#      ItemNum  Prediction
# 0        552   79.490574
# 1         16   90.738689
# 2        441   98.182344
# 3        219  130.520666
# 4        600   73.034483
# ..       ...         ...
# 196      612   84.559487
# 197      315   67.446153
# 198      509   67.747024
# 199      550   94.040717
# 200      290   68.901606
#
# [201 rows x 2 columns]

# %%
df.to_csv("Unibuc-FMI_Response_time_predictions_run3_8.csv")

# %%
from scipy.stats import pearsonr, kendalltau
from sklearn.metrics import mean_squared_error

true_labels = labels_test.numpy().reshape(-1, 1)
true_labels = scaler_time.inverse_transform(true_labels).flatten()

mse  = mean_squared_error(true_labels, predictions)
rmse = np.sqrt(mse)
pearson_r, pearson_p = pearsonr(true_labels, predictions)
kendall_tau, kendall_p = kendalltau(true_labels, predictions)

print("=== Test Set Evaluation ===")
print(f"  MSE              : {mse:.4f}")
print(f"  RMSE             : {rmse:.4f}")
print(f"  Pearson r        : {pearson_r:.4f}  (p={pearson_p:.4e})")
print(f"  Kendall tau      : {kendall_tau:.4f}  (p={kendall_p:.4e})")

plt.figure(figsize=(6, 6))
plt.scatter(true_labels, predictions, alpha=0.6, edgecolors='k', linewidths=0.5)
plt.plot([true_labels.min(), true_labels.max()], [true_labels.min(), true_labels.max()], 'r--', label='Perfect prediction')
plt.xlabel('True Response Time')
plt.ylabel('Predicted Response Time')
plt.title(f'Predicted vs True Response Time\nPearson r={pearson_r:.3f}, Kendall τ={kendall_tau:.3f}')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# === Test Set Evaluation ===
#   MSE              : 740.1156
#   RMSE             : 27.2051
#   Pearson r        : 0.5469  (p=4.5004e-17)
#   Kendall tau      : 0.4275  (p=2.0427e-19)
